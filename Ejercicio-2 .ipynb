# %%
# Primera parte de la Actividad de la Lección 2 
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({"X": [10,20,30,40,50], "Y": [15,5,10,8,6]})
df.head()
# Out:
#     X   Y
# 0  10  15
# 1  20   5
# 2  30  10
# 3  40   8
# 4  50   6

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot()
plt.show()

# %%
df.plot(kind="bar")
plt.show()

# %%
df.plot(kind="bar", stacked=True)
plt.show()

# %%
df.plot(kind="bar", stacked=True, grid=True, title="Gráfica ejemplo con pandas")
plt.show()

# %%
df.Y.value_counts()
# Out:
# 15    1
# 5     1
# 10    1
# 8     1
# 6     1
# Name: Y, dtype: int64

# %%
df.Y.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df_2 = pd.DataFrame({"X": [10,20,30,40,50,60,70,80], "y":[10,20,10,40,20,30,20,10]})
df_2
# Out:
#     X   y
# 0  10  10
# 1  20  20
# 2  30  10
# 3  40  40
# 4  50  20
# 5  60  30
# 6  70  20
# 7  80  10

# %%
df_2.y.value_counts().plot(kind="bar")
plt.show()

# %%
df_2.y.value_counts().plot(kind="bar", color=['red','blue','green', 'orange'])
plt.show()

# %%
# SEGUNDA parte de la Actividad de la Lección 2 
# Hacer las gráficas para Iris Dataset con “plotnine”.

# %%
# Importamos las librerías necesarias
from plotnine import *
import pandas as pd
df = pd.read_csv('iris.csv')

# Cargamos los datos de Iris Dataset en un DataFrame de pandas
iris_df = pd.DataFrame(data=df)

# Creamos una gráfica de dispersión
ggplot(iris_df, aes(x='sepal.length', y='sepal.width', color='variety')) + \
geom_point() + \
labs(title='Gráfica de dispersión de Iris Dataset', x='Longitud del sépalo', y='Anchura del sépalo')
# Out:
# <ggplot: (8783508986603)>

# %%
# Tercera parte de la Actividad de la Lección 2 
#¿ Existe alguna forma de programar, o de integrar Python con Tableau ?

# %%
#Sí, es posible integrar Python con Tableau utilizando la función de Análisis de Script Python en Tableau. Esta función permite integrar código Python en una visualización de Tableau para llevar a cabo tareas de análisis y procesamiento de datos que no se pueden realizar con las funciones integradas de Tableau.
#Esto se puede hacer desde el menú Ayuda en Tableau Desktop, seleccionando "Configuración y rendimiento" y luego "Gestión de fuentes de datos externas. A continuación, debes seleccionar la versión de Python que deseas utilizar y establecer la ruta de acceso al ejecutable de Python.

# %% [markdown]
# ![Captura%20de%20pantalla%20de%202023-03-26%2018-34-03.png](attachment:Captura%20de%20pantalla%20de%202023-03-26%2018-34-03.png)

# %%
# Cuarta parte de la Actividad de la Lección 2
#Se pedirá en este caso que se tome uno de ellos, y se trate de aprender de
#forma autodidacta, se pedirá que en el mismo archivo .ipynb se presente algo
#relacionado con Bokeh preferentemente, o de Power BI.
#No es importante la elección, pudiera ser Folium, Savvy, o incluso alguna cosa no vista.

# %%
import folium
# Crea un objeto de mapa centrado en una ubicación específica
mi_mapa = folium.Map(location=[40.4637, -3.7492], zoom_start=10)
# Agrega un marcador en la ubicación del centro de Madrid
folium.Marker(location=[40.4168, -3.7038],
              popup='Centro de Madrid').add_to(mi_mapa)
# Agrega un marcador en la ubicación del centro de Madrid
folium.Marker(location=[40.4168, -3.7038],
              popup='Centro de Madrid').add_to(mi_mapa)
# Guarda el objeto de mapa como un archivo HTML
mi_mapa.save('mapa.html')

# %%
## El código anterior genera este archivo html donde podemos ver un mapa del centro de Madrid


<!DOCTYPE html>
<html>
<head>
    
    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
    
        <script>
            L_NO_TOUCH = false;
            L_DISABLE_3D = false;
        </script>
    
    <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
    <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
    <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>
    <script src="https://code.jquery.com/jquery-1.12.4.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>
    <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>
    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>
    <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css"/>
    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
    <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
    
            <meta name="viewport" content="width=device-width,
                initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
            <style>
                #map_b79845a1c53ac74b53efc7d23a709319 {
                    position: relative;
                    width: 100.0%;
                    height: 100.0%;
                    left: 0.0%;
                    top: 0.0%;
                }
                .leaflet-container { font-size: 1rem; }
            </style>
        
</head>
<body>
    
    
            <div class="folium-map" id="map_b79845a1c53ac74b53efc7d23a709319" ></div>
        
</body>
<script>
    
    
            var map_b79845a1c53ac74b53efc7d23a709319 = L.map(
                "map_b79845a1c53ac74b53efc7d23a709319",
                {
                    center: [40.4637, -3.7492],
                    crs: L.CRS.EPSG3857,
                    zoom: 10,
                    zoomControl: true,
                    preferCanvas: false,
                }
            );

            

        
    
            var tile_layer_e0e25b7f235bb6ba065bf3c99b06aa0e = L.tileLayer(
                "https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
                {"attribution": "Data by \u0026copy; \u003ca target=\"_blank\" href=\"http://openstreetmap.org\"\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\"_blank\" href=\"http://www.openstreetmap.org/copyright\"\u003eODbL\u003c/a\u003e.", "detectRetina": false, "maxNativeZoom": 18, "maxZoom": 18, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}
            ).addTo(map_b79845a1c53ac74b53efc7d23a709319);
        
    
            var marker_3376dcfc067a2de4686122d7467de041 = L.marker(
                [40.4168, -3.7038],
                {}
            ).addTo(map_b79845a1c53ac74b53efc7d23a709319);
        
    
        var popup_527bc427eafadd4decf6d8fc4121960e = L.popup({"maxWidth": "100%"});

        
            
                var html_ae3f1f0cca259a7b9571b5dc8fc19906 = $(`<div id="html_ae3f1f0cca259a7b9571b5dc8fc19906" style="width: 100.0%; height: 100.0%;">Centro de Madrid</div>`)[0];
                popup_527bc427eafadd4decf6d8fc4121960e.setContent(html_ae3f1f0cca259a7b9571b5dc8fc19906);
            
        

        marker_3376dcfc067a2de4686122d7467de041.bindPopup(popup_527bc427eafadd4decf6d8fc4121960e)
        ;

        
    
    
            var marker_5033cf73e386d4e776506230f7756413 = L.marker(
                [40.4168, -3.7038],
                {}
            ).addTo(map_b79845a1c53ac74b53efc7d23a709319);
        
    
        var popup_6e9f3d061b02cdc72165a22d890b0f7f = L.popup({"maxWidth": "100%"});

        
            
                var html_53aeb2997a84367353eb62da3d177457 = $(`<div id="html_53aeb2997a84367353eb62da3d177457" style="width: 100.0%; height: 100.0%;">Centro de Madrid</div>`)[0];
                popup_6e9f3d061b02cdc72165a22d890b0f7f.setContent(html_53aeb2997a84367353eb62da3d177457);
            
        

        marker_5033cf73e386d4e776506230f7756413.bindPopup(popup_6e9f3d061b02cdc72165a22d890b0f7f)
        ;

        
    
</script>
</html>
# Out:
#   File <tokenize>:36
#     }
#     ^
# IndentationError: unindent does not match any outer indentation level
